# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
df = pd.read_csv('CENSUS.csv')
df
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY     STNAME             CTYNAME  \
# 0         40       3         6      1       0    Alabama             Alabama
# 1         50       3         6      1       1    Alabama      Autauga County
# 2         50       3         6      1       3    Alabama      Baldwin County
# 3         50       3         6      1       5    Alabama      Barbour County
# 4         50       3         6      1       7    Alabama         Bibb County
# 5         50       3         6      1       9    Alabama       Blount County
# 6         50       3         6      1      11    Alabama      Bullock County
# 7         50       3         6      1      13    Alabama       Butler County
# 8         50       3         6      1      15    Alabama      Calhoun County
# 9         50       3         6      1      17    Alabama     Chambers County
# 10        50       3         6      1      19    Alabama     Cherokee County
# ...

# %%
#以每个州人口最多的 3 个县的人口总和为这个州人口的衡量标准，哪 3 个州人口最多？
#先按州分组，再对每个州内的县进行排序选出人口最多的 3 个县求和，作为每个州的人口数，最后排序。

#1.获取所有县的数据，然后根据州进行分组排序
country = df[df['SUMLEV'] == 50]
def fn(x,n = 3):
    d = x.sort_values('CENSUS2010POP',ascending = False)[:n]
    return d['CENSUS2010POP'].sum()
st = country.loc[:,['CTYNAME','CENSUS2010POP']].groupby(country['STNAME']).apply(fn)
# st
# st.sort_values(ascending = False).head(3)

# %%
#在 2010 年至 2015 年间人口变化幅度最大的是哪个县？
#对于每个县，计算 2010-2015 年的人口数的最大值和最小值，求出差值即变化幅度，再对差值进行排序找出变化幅度最大的县。
country = df[df['SUMLEV'] == 50]

# print(country)
# new = country[['POPESTIMATE2010',
#          'POPESTIMATE2011',
#          'POPESTIMATE2012',
#          'POPESTIMATE2013',
#          'POPESTIMATE2014',
#          'POPESTIMATE2015']].apply(lambda x:x.max()-x.min(),axis = 1).argmax()#返回最大值索引

# new
# country.loc[new,['CTYNAME']]


new = country[['POPESTIMATE2010',
         'POPESTIMATE2011',
         'POPESTIMATE2012',
         'POPESTIMATE2013',
         'POPESTIMATE2014',
         'POPESTIMATE2015']].groupby(country['CTYNAME']).apply(lambda x : x.min())

# def fn(x):
#     return x.max() - x.min()


new#.loc[:].apply(fn,axis = 1).sort_values(ascending = False).head(1)
# Out:
#                             POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  \
# CTYNAME
# Abbeville County                      25338            25105            25051
# Acadia Parish                         61856            61763            61850
# Accomack County                       33165            33287            33314
# Ada County                           393464           401088           408921
# Adair County                           7665             7562             7488
# Adams County                           2349             2304             2317
# Addison County                        36820            36873            36852
# Aiken County                         160551           161816           163274
# Aitkin County                         16219            16105            15934
# Alachua County                       247625           249688           251669
# Alamance County                      151581           152947           153822
# ...
