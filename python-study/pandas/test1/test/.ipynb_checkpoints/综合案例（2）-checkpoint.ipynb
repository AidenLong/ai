# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # 1.以每个州人口最多的 3 个县的人口总和为这个州人口的衡量标准，哪 3 个州人口最多？

# %%
census_df = pd.read_csv('census.csv')
census_df
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY     STNAME             CTYNAME  \
# 0         40       3         6      1       0    Alabama             Alabama
# 1         50       3         6      1       1    Alabama      Autauga County
# 2         50       3         6      1       3    Alabama      Baldwin County
# 3         50       3         6      1       5    Alabama      Barbour County
# 4         50       3         6      1       7    Alabama         Bibb County
# 5         50       3         6      1       9    Alabama       Blount County
# 6         50       3         6      1      11    Alabama      Bullock County
# 7         50       3         6      1      13    Alabama       Butler County
# 8         50       3         6      1      15    Alabama      Calhoun County
# 9         50       3         6      1      17    Alabama     Chambers County
# 10        50       3         6      1      19    Alabama     Cherokee County
# ...

# %%
only_county = census_df[census_df['SUMLEV'] == 50]


def top(df, n=3, column='CENSUS2010POP'):
    return df.sort_values(column, ascending=False)[:n]['CENSUS2010POP'].sum()


grouped = only_county[['STNAME', 'CTYNAME', 'CENSUS2010POP']].groupby('STNAME').apply(top)
grouped.sort_values(ascending=False)[:3].index.tolist()
# Out:
# ['California', 'Texas', 'Illinois']

# %% [markdown]
# # 2.在 2010 年至 2012 年间人口平均量是怎么样的

# %%
only_county = census_df[census_df['SUMLEV'] == 50]


def get_change(row):
    pop_year = row[
        ['POPESTIMATE2010','POPESTIMATE2011', 'POPESTIMATE2012']
   ]
    return pop_year.mean()


popestimete=only_county.apply(get_change, axis=1)
popestimete
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-0dd7d86c542e> in <module>()
#       9
#      10
# ---> 11 popestimete=only_county.groupby['CTYNAME'].apply(get_change, axis=1)
#      12 popestimete
#
# TypeError: 'method' object is not subscriptable

# %% [markdown]
# ## 3.在 2010 年至 2012 年间人口变化幅度最大的是哪个县

# %%
only_county = census_df[census_df['SUMLEV'] == 50]
def get_max_min(row):
    pop_year = row[
        ['POPESTIMATE2010','POPESTIMATE2011', 'POPESTIMATE2012']
   ]
    print(pop_year)
    return pop_year.max()-pop_year.min()
only_county.loc[only_county.apply(get_max_min, axis=1).idxmax()]['CTYNAME']
# Out:
# POPESTIMATE2010    54660
# POPESTIMATE2011    55253
# POPESTIMATE2012    55175
# Name: 1, dtype: object
# POPESTIMATE2010    183193
# POPESTIMATE2011    186659
# POPESTIMATE2012    190396
# Name: 2, dtype: object
# POPESTIMATE2010    27341
# POPESTIMATE2011    27226
# POPESTIMATE2012    27159
# Name: 3, dtype: object
# POPESTIMATE2010    22861
# POPESTIMATE2011    22733
# POPESTIMATE2012    22642
# Name: 4, dtype: object
# POPESTIMATE2010    57373
# POPESTIMATE2011    57711
# POPESTIMATE2012    57776
# Name: 5, dtype: object
# POPESTIMATE2010    10887
# POPESTIMATE2011    10629
# POPESTIMATE2012    10606
# Name: 6, dtype: object
# POPESTIMATE2010    20944
# POPESTIMATE2011    20673
# POPESTIMATE2012    20408
# Name: 7, dtype: object
# POPESTIMATE2010    118437
# POPESTIMATE2011    117768
# POPESTIMATE2012    117286
# Name: 8, dtype: object
# POPESTIMATE2010    34098
# POPESTIMATE2011    33993
# POPESTIMATE2012    34075
# Name: 9, dtype: object
# POPESTIMATE2010    25976
# ...
