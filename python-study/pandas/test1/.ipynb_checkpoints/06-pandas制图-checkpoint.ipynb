# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

mpl.rcParams['font.sans-serif'] = ['SimHei']
mpl.rcParams['axes.unicode_minus'] = False

# %matplotlib inline

# %%
#series 制图
data1 = np.random.randint(700,1000,12)
data2 = np.random.randint(800,1000,12)

ser1 = pd.Series(data1,index = [str(i)+'月' for i in np.arange(1,13)])#
ser2 = pd.Series(data2,index = [str(i)+'月' for i in np.arange(1,13)])
ser1.plot(label = '鼓浪屿',style = 'r--o',yticks=(np.linspace(500,1000,5)))
ser2.plot(label = '张家界',style = 'g-o',yticks=(np.linspace(500,1000,5)))


#设置标签
plt.xlabel('月份')
plt.ylabel('人次/百万')
plt.title('游客流量表')

plt.legend()
# plt.show()
# np.arange(500,1100,100)

# %%
data = np.random.randint(700,1000,(12,3))
df = pd.DataFrame(data,index =  [str(i)+'月' for i in np.arange(1,13)],columns = ['鼓浪屿','张家界','上海'])

df.plot(figsize = (8,5),style = ['r-o','g--o','m-.o'])


#设置标签
plt.xlabel('月份')
plt.ylabel('人次/百万')
plt.title('游客流量表')

# plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-13136e97f906> in <module>
#       2 df = pd.DataFrame(data,index =  [str(i)+'月' for i in np.arange(1,13)],columns = ['鼓浪屿','张家界','上海'])
#       3
# ----> 4 df.plot(figsize = (8,5),style = ['r-o','g--o','m-.0'])
#       5
#       6
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
#    2940                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2941                           sort_columns=sort_columns, **kwds)
#    2942     __call__.__doc__ = plot_frame.__doc__
#    2943
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1975                  yerr=yerr, xerr=xerr,
#    1976                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1977                  **kwds)
#    1978
#    1979
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1802         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1803
# -> 1804     plot_obj.generate()
#    1805     plot_obj.draw()
#    1806     return plot_obj.result
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in generate(self)
#     258         self._compute_plot_data()
#     259         self._setup_subplots()
# --> 260         self._make_plot()
#     261         self._add_table()
#     262         self._make_legend()
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _make_plot(self)
#     983                              stacking_id=stacking_id,
#     984                              is_errorbar=is_errorbar,
# --> 985                              **kwds)
#     986             self._add_legend_handle(newlines[0], label, index=i)
#     987
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _plot(cls, ax, x, y, style, column_num, stacking_id, **kwds)
#     999             cls._initialize_stacker(ax, stacking_id, len(y))
#    1000         y_values = cls._get_stacked_values(ax, stacking_id, y, kwds['label'])
# -> 1001         lines = MPLPlot._plot(ax, x, y_values, style=style, **kwds)
#    1002         cls._update_stacker(ax, stacking_id, y)
#    1003         return lines
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _plot(cls, ax, x, y, style, is_errorbar, **kwds)
#     613             else:
#     614                 args = (x, y)
# --> 615             return ax.plot(*args, **kwds)
#     616
#     617     def _get_index_name(self):
#
# D:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# D:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1609         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
#    1610
# -> 1611         for line in self._get_lines(*args, **kwargs):
#    1612             self.add_line(line)
#    1613             lines.append(line)
#
# D:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _grab_next_args(self, *args, **kwargs)
#     391                 this += args[0],
#     392                 args = args[1:]
# --> 393             yield from self._plot_args(this, kwargs)
#     394
#     395
#
# D:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     340         ret = []
#     341         if len(tup) > 1 and isinstance(tup[-1], str):
# --> 342             linestyle, marker, color = _process_plot_format(tup[-1])
#     343             tup = tup[:-1]
#     344         elif len(tup) == 3:
#
# D:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _process_plot_format(fmt)
#     116         else:
#     117             raise ValueError(
# --> 118                 'Unrecognized character %c in format string' % c)
#     119         i += 1
#     120
#
# ValueError: Unrecognized character 0 in format string

# %% [markdown]
# 柱状图

# %%
ser1 = pd.Series(data1,index = [str(i)+'月' for i in np.arange(1,13)])#
ser2 = pd.Series(data2,index = [str(i)+'月' for i in np.arange(1,13)])

ser1.plot(figsize = (10,8),kind = 'bar',color = 'lightskyblue',width = -0.2,align = 'edge')
ser2.plot(figsize = (10,8),kind = 'bar',color = 'yellowgreen',width = 0.2,align = 'edge')

plt.show()

# %%
data = np.random.randint(700,1000,(12,2))
df = pd.DataFrame(data,index =  [str(i)+'月' for i in np.arange(1,13)],columns = ['鼓浪屿','张家界'])
df.plot(kind = 'bar',figsize = (8,5),rot= 90*np.pi/180)

plt.show()
